# %% [markdown]
# # Assessing
# Use the space below to explore `all_alpha_08.csv` and `all_alpha_18.csv` to answer the quiz questions below.

# %%
import pandas as pd
df_08 = pd.read_csv('all_alpha_08.csv')
df_18 = pd.read_csv('all_alpha_18.csv')

# %% [markdown]
# # 2008 FUEL ECONOMY DATA

# %%
df_08.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID    Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 0  8HNXT03.7PKR          SUV                   7          Drv       15
# 1  8HNXT03.7PKR          SUV                   6          Drv       15
# 2  8HNXT02.3DKR          SUV                   7          Drv       17
# 3  8HNXT02.3DKR          SUV                   6          Drv       17
# 4  8HNXV03.5HKR  midsize car                   7          Drv       16
#
#   Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %%
df_08.shape
# Out:
# (2404, 18)

# %%
sum(df_08.duplicated())
# Out:
# 25

# %%
df_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 2404 non-null   object
#  1   Displ                 2404 non-null   float64
#  2   Cyl                   2205 non-null   object
#  3   Trans                 2205 non-null   object
#  4   Drive                 2311 non-null   object
#  5   Fuel                  2404 non-null   object
#  6   Sales Area            2404 non-null   object
#  7   Stnd                  2404 non-null   object
#  8   Underhood ID          2404 non-null   object
#  9   Veh Class             2404 non-null   object
#  10  Air Pollution Score   2404 non-null   object
#  11  FE Calc Appr          2205 non-null   object
#  12  City MPG              2205 non-null   object
#  13  Hwy MPG               2205 non-null   object
#  14  Cmb MPG               2205 non-null   object
# ...

# %%
df_08[df_08.isnull().any(axis=1)].shape[0]
# Out:
# 199

# %%
for column in df_08.columns:
    print('{} : {} \n'.format(column, df_08[column].dropna().unique().size))
df_08['Fuel'].unique()
# Out:
# Model : 436
#
# Displ : 47
#
# Cyl : 8
#
# Trans : 14
#
# Drive : 2
#
# Fuel : 5
#
# Sales Area : 3
#
# Stnd : 12
#
# Underhood ID : 343
#
# Veh Class : 9
#
# Air Pollution Score : 13
#
# FE Calc Appr : 2
#
# City MPG : 39
#
# Hwy MPG : 43
#
# Cmb MPG : 38
#
# Unadj Cmb MPG : 721
#
# Greenhouse Gas Score : 20
#
# SmartWay : 2
# array(['Gasoline', 'ethanol/gas', 'ethanol', 'diesel', 'CNG'],
#       dtype=object)

# %%
df_18['Fuel'].unique()
# Out:
# array(['Gasoline', 'Gasoline/Electricity', 'Diesel', 'Ethanol/Gas',
#        'Electricity'], dtype=object)

# %% [markdown]
# # 2018 FUEL ECONOMY DATA

# %%
df_18.head()
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region       Stnd  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA     T3B125
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA         U2
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA     T3B125
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA         U2
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  L3ULEV125
#
#              Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 1      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 2      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 3      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 4  California LEV-III ULEV125  JHNXV02.4WH3  small car                    3
#
# ...

# %%
df_18.shape
# Out:
# (1611, 18)

# %%
sum(df_18.duplicated())
# Out:
# 0

# %%
df_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 1611 non-null   object
#  1   Displ                 1609 non-null   float64
#  2   Cyl                   1609 non-null   float64
#  3   Trans                 1611 non-null   object
#  4   Drive                 1611 non-null   object
#  5   Fuel                  1611 non-null   object
#  6   Cert Region           1611 non-null   object
#  7   Stnd                  1611 non-null   object
#  8   Stnd Description      1611 non-null   object
#  9   Underhood ID          1611 non-null   object
#  10  Veh Class             1611 non-null   object
#  11  Air Pollution Score   1611 non-null   int64
#  12  City MPG              1611 non-null   object
#  13  Hwy MPG               1611 non-null   object
#  14  Cmb MPG               1611 non-null   object
# ...

# %%
df_18[df_18.isnull().any(axis=1)].shape[0]
# Out:
# 2

# %%
for column in df_18.columns:
    print('{} : {}'.format(column, df_18[column].dropna().unique().size))
# Out:
# Model : 367
# Displ : 36
# Cyl : 7
# Trans : 26
# Drive : 2
# Fuel : 5
# Cert Region : 2
# Stnd : 19
# Stnd Description : 19
# Underhood ID : 230
# Veh Class : 9
# Air Pollution Score : 6
# City MPG : 58
# Hwy MPG : 62
# Cmb MPG : 57
# Greenhouse Gas Score : 10
# SmartWay : 3
# Comb CO2 : 299

# %%
df_18['Fuel'].unique()
# Out:
# array(['Gasoline', 'Gasoline/Electricity', 'Diesel', 'Ethanol/Gas',
#        'Electricity'], dtype=object)

# %% [markdown]
# # Cleaning Column Labels
#
# ## Drop Extraneous Columns

# %%
# drop columns from 2008 dataset
df_08.drop(['Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'], axis=1, inplace=True)

# confirm changes
df_08.head(1)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Veh Class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA       SUV
#
#   Air Pollution Score City MPG Hwy MPG Cmb MPG Greenhouse Gas Score SmartWay
# 0                   7       15      20      17                    4       no

# %%
# drop columns from 2008 dataset
df_18.drop(['Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2'], axis=1, inplace=True)

# confirm changes
df_18.head(1)
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region  Veh Class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
#
#    Air Pollution Score City MPG Hwy MPG Cmb MPG  Greenhouse Gas Score SmartWay
# 0                    3       20      28      23                     5       No

# %% [markdown]
# ## Rename Columns

# %%
df_08.rename(columns={"Sales Area": "Cert Region"}, inplace=True)
df_08.head(1)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Cert Region Veh Class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA       SUV
#
#   Air Pollution Score City MPG Hwy MPG Cmb MPG Greenhouse Gas Score SmartWay
# 0                   7       15      20      17                    4       no

# %%
# replace spaces with underscores and lowercase labels for 2008 dataset
df_08.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)

# confirm changes
df_08.head(1)
# Out:
#        model  displ      cyl    trans drive      fuel cert_region veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA       SUV
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no

# %%
# replace spaces with underscores and lowercase labels for 2008 dataset
df_18.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)

# confirm changes
df_18.head(1)
# Out:
#        model  displ  cyl       trans drive      fuel cert_region  veh_class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 0                    3       20      28      23                     5       No

# %%
# confirm column labels for 2008 and 2018 datasets are identical
df_08.columns == df_18.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
# make sure they're all identical like this
(df_08.columns == df_18.columns).all()
# Out:
# True

# %%
# save new datasets for next section
df_08.to_csv('data_08_v1.csv', index=False)
df_18.to_csv('data_18_v1.csv', index=False)

# %% [markdown]
# # Filter, Drop Nulls, Dedupe

# %%
df_08v = pd.read_csv('data_08_v1.csv')
df_18v = pd.read_csv('data_18_v1.csv')

# %%
df_08v.shape
# Out:
# (2404, 14)

# %%
df_18v.shape
# Out:
# (1611, 14)

# %% [markdown]
# ## Filter by Certification Region

# %%
# filter datasets for rows following California standards
df_08v = df_08v.query('cert_region == "CA"')
df_18v = df_18v.query('cert_region == "CA"')

# %%
# confirm only certification region is California
df_08v['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
# confirm only certification region is California
df_18v['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
# drop certification region columns form both datasets
df_08v.drop(['cert_region'], axis=1, inplace=True)

# %%
df_18v.drop(['cert_region'], axis=1, inplace=True)

# %%
df_08v.shape
# Out:
# (1084, 13)

# %%
df_18v.shape
# Out:
# (798, 13)

# %% [markdown]
# ## Drop Rows with Missing Values

# %%
# view missing value count for each feature in 2008
df_08v.isnull().sum()
# Out:
# model                    0
# displ                    0
# cyl                     75
# trans                   75
# drive                   37
# fuel                     0
# veh_class                0
# air_pollution_score      0
# city_mpg                75
# hwy_mpg                 75
# cmb_mpg                 75
# greenhouse_gas_score    75
# smartway                 0
# dtype: int64

# %%
# view missing value count for each feature in 2018
df_18v.isnull().sum()
# Out:
# model                   0
# displ                   1
# cyl                     1
# trans                   0
# drive                   0
# fuel                    0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
# drop rows with any null values in both datasets
df_08v = df_08v.dropna()
df_18v = df_18v.dropna()

# %%
# checks if any of columns in 2008 have null values - should print False
df_08v.isnull().sum().any()
# Out:
# False

# %%
# checks if any of columns in 2018 have null values - should print False
df_18v.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ## Dedupe Data

# %%
# print number of duplicates in 2008 and 2018 datasets
df_08v.duplicated().sum()
# Out:
# 23

# %%
df_18v.duplicated().sum()
# Out:
# 3

# %%
# drop duplicates in both datasets
df_08v.drop_duplicates(inplace=True)
df_18v.drop_duplicates(inplace=True)

# %%
# print number of duplicates again to confirm dedupe - should both be 0
df_08v.duplicated().sum()
# Out:
# 0

# %%
df_18v.duplicated().sum()
# Out:
# 0

# %%
# save progress for the next section
df_08v.to_csv('data_08_v2.csv', index=False)
df_18v.to_csv('data_18_v2.csv', index=False)

# %% [markdown]
# # FIXING DATA TYPES PART 1

# %%
df_08v2 = pd.read_csv('data_08_v2.csv')
df_18v2 = pd.read_csv('data_18_v2.csv')

# %%
df

# %%
# check value counts for the 2008 cyl column
df_08v2['cyl'].value_counts()
# Out:
# (6 cyl)     409
# (4 cyl)     283
# (8 cyl)     199
# (5 cyl)      48
# (12 cyl)     30
# (10 cyl)     14
# (2 cyl)       2
# (16 cyl)      1
# Name: cyl, dtype: int64

# %%
# Extract int from strings in the 2008 cyl column
df_08v2['cyl'] = df_08v2['cyl'].str.extract('(\d+)').astype(int)

# %%
# Check value counts for 2008 cyl column again to confirm the change
df_08v2['cyl'].value_counts()
# Out:
# 6     409
# 4     283
# 8     199
# 5      48
# 12     30
# 10     14
# 2       2
# 16      1
# Name: cyl, dtype: int64

# %%
# convert 2018 cyl column to int
df_18v2['cyl'] = df_18v2['cyl'].astype(int)

# %%
df_18v2['cyl'].value_counts()
# Out:
# 4     365
# 6     246
# 8     153
# 3      18
# 12      9
# 5       2
# 16      1
# Name: cyl, dtype: int64

# %%
df_08v2.to_csv('data_08_v3.csv', index=False)
df_18v2.to_csv('data_18_v3.csv', index=False)

# %% [markdown]
# # FIXING DATA TYPES PART 2

# %%
df_08v3 = pd.read_csv('data_08_v3.csv')
df_18v3 = pd.read_csv('data_18_v3.csv')

# %%
df_08v3.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 1  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 2   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 3   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 4   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no
# 1                   7       17      22      19                    5       no
# 2                   7       16      24      19                    5       no
# 3                   7       18      26      21                    6      yes
# 4                   7       17      26      20                    6      yes

# %%
# try using pandas' to_numeric or astype function to convert the
# 2008 air_pollution_score column to float -- this won't work
# Throws a ValueError: could not convert string to float: '6/4'
df_08v3['air_pollution_score'].astype(float)

# %%
# First, let's get all the hybrids in 2008
hb_08 = df_08v3[df_08v3['fuel'].str.contains('/')]
hb_08
# Out:
#                   model  displ  cyl    trans drive         fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                 6/4    13/18   19/25   15/21                  7/6       no

# %%
df_08v3.shape
# Out:
# (986, 13)

# %%
hb_18 = df_18v3[df_18v3['fuel'].str.contains('/')]
hb_18
# Out:
#                                  model  displ  cyl       trans drive  \
# 52                            BMW 330e    2.0    4  SemiAuto-8   2WD
# 78                            BMW 530e    2.0    4  SemiAuto-8   2WD
# 79                            BMW 530e    2.0    4  SemiAuto-8   4WD
# 92                            BMW 740e    2.0    4  SemiAuto-8   4WD
# 189                   CHEVROLET Impala    3.6    6  SemiAuto-6   2WD
# 195             CHEVROLET Silverado 15    4.3    6      Auto-6   2WD
# 196             CHEVROLET Silverado 15    4.3    6      Auto-6   4WD
# 197             CHEVROLET Silverado 15    5.3    8      Auto-6   2WD
# 212            CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD
# 214            CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD
# 216               CHEVROLET Tahoe 1500    5.3    8      Auto-6   2WD
# 218               CHEVROLET Tahoe 1500    5.3    8      Auto-6   4WD
# 225                     CHEVROLET Volt    1.5    4         CVT   2WD
# ...

# %%
# create two copies of the 2008 hybrids dataframe
df1 = hb_08.copy()  # data on first fuel type of each hybrid vehicle
df2 = hb_08.copy()  # data on second fuel type of each hybrid vehicle

# Each one should look like this
df1
# Out:
#                   model  displ  cyl    trans drive         fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                 6/4    13/18   19/25   15/21                  7/6       no

# %%
df2
# Out:
#                   model  displ  cyl    trans drive         fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                 6/4    13/18   19/25   15/21                  7/6       no

# %%
# columns to split by "/"
split_columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])

# %%
# this dataframe holds info for the FIRST fuel type of the hybrid
# aka the values before the "/"s
df1
# Out:
#                   model  displ  cyl    trans drive     fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                   6       13      19      15                    7       no

# %%
# this dataframe holds info for the SECOND fuel type of the hybrid
# aka the values after the "/"s
df2
# Out:
#                   model  displ  cyl    trans drive fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                   4       18      25      21                    6       no

# %%
# combine dataframes to add to the original dataframe
new_rows = df1.append(df2)

# now we have separate rows for each fuel type of each vehicle!
new_rows
# Out:
#                   model  displ  cyl    trans drive     fuel  veh_class  \
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
# 582  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD      gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 582                   6       13      19      15                    7       no
# 582                   4       18      25      21                    6       no

# %%
hb_08.index
# Out:
# Int64Index([582], dtype='int64')

# %%
# drop the original hybrid rows
df_08v3.drop(hb_08.index, inplace=True)

# add in our newly separated rows
df_08v3 = df_08v3.append(new_rows, ignore_index=True)

# %%
# check that all the original hybrid rows with "/"s are gone
df_08v3[df_08v3['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_08v3.shape
# Out:
# (987, 13)

# %%
# create two copies of the 2018 hybrids dataframe, hb_18
df1_18 = hb_18.copy()
df2_18 = hb_18.copy()

df1_18
# Out:
#                                  model  displ  cyl       trans drive  \
# 52                            BMW 330e    2.0    4  SemiAuto-8   2WD
# 78                            BMW 530e    2.0    4  SemiAuto-8   2WD
# 79                            BMW 530e    2.0    4  SemiAuto-8   4WD
# 92                            BMW 740e    2.0    4  SemiAuto-8   4WD
# 189                   CHEVROLET Impala    3.6    6  SemiAuto-6   2WD
# 195             CHEVROLET Silverado 15    4.3    6      Auto-6   2WD
# 196             CHEVROLET Silverado 15    4.3    6      Auto-6   4WD
# 197             CHEVROLET Silverado 15    5.3    8      Auto-6   2WD
# 212            CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD
# 214            CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD
# 216               CHEVROLET Tahoe 1500    5.3    8      Auto-6   2WD
# 218               CHEVROLET Tahoe 1500    5.3    8      Auto-6   4WD
# 225                     CHEVROLET Volt    1.5    4         CVT   2WD
# ...

# %%
df2_18
# Out:
#                                  model  displ  cyl       trans drive  \
# 52                            BMW 330e    2.0    4  SemiAuto-8   2WD
# 78                            BMW 530e    2.0    4  SemiAuto-8   2WD
# 79                            BMW 530e    2.0    4  SemiAuto-8   4WD
# 92                            BMW 740e    2.0    4  SemiAuto-8   4WD
# 189                   CHEVROLET Impala    3.6    6  SemiAuto-6   2WD
# 195             CHEVROLET Silverado 15    4.3    6      Auto-6   2WD
# 196             CHEVROLET Silverado 15    4.3    6      Auto-6   4WD
# 197             CHEVROLET Silverado 15    5.3    8      Auto-6   2WD
# 212            CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD
# 214            CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD
# 216               CHEVROLET Tahoe 1500    5.3    8      Auto-6   2WD
# 218               CHEVROLET Tahoe 1500    5.3    8      Auto-6   4WD
# 225                     CHEVROLET Volt    1.5    4         CVT   2WD
# ...

# %%
# list of columns to split
split_columns_18 = ['fuel', 'city_mpg', 'hwy_mpg', 'cmb_mpg']

# apply split function to each column of each dataframe copy
for c in split_columns_18:
    df1_18[c] = df1_18[c].apply(lambda x:x.split("/")[0])
    df2_18[c] = df2_18[c].apply(lambda x:x.split("/")[1])

# %%
# append the two dataframes
new_rows_18 = df1_18.append(df2_18)

# drop each hybrid row from the original 2018 dataframe
# do this by using pandas' drop function with hb_18's index
df_18v3.drop(hb_18.index, inplace=True)

# append new_rows to df_18v3
df_18v3 = df_18v3.append(new_rows_18, ignore_index=True)

# %%
df_18v3[df_18v3['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_18v3.shape
# Out:
# (832, 13)

# %%
# convert string to float for 2008 air pollution column
df_08v3['air_pollution_score'] = df_08v3['air_pollution_score'].astype(float)

# %%
# convert int to float for 2018 air pollution column
df_18v3['air_pollution_score'] = df_18v3['air_pollution_score'].astype(float)

# %%
df_08v3.to_csv('data_08_v4.csv', index=False)
df_18v3.to_csv('data_18_v4.csv', index=False)

# %% [markdown]
# # FIXING DATA TYPES PART 3

# %%
df_08v4 = pd.read_csv('data_08_v4.csv')
df_18v4 = pd.read_csv('data_18_v4.csv')

# %%
# convert mpg columns to floats
mpg_columns = ['city_mpg', 'hwy_mpg', 'cmb_mpg']
for c in mpg_columns:
    df_18v4[c] = df_18v4[c].astype(float)
    df_08v4[c] = df_08v4[c].astype(float)

# %%
# convert from float to int
df_08v4['greenhouse_gas_score'] = df_08v4['greenhouse_gas_score'].astype(int)

# %%
df_08v4.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 1  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 2   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 3   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 4   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  7.0      15.0     20.0     17.0                     4
# 1                  7.0      17.0     22.0     19.0                     5
# 2                  7.0      16.0     24.0     19.0                     5
# 3                  7.0      18.0     26.0     21.0                     6
# 4                  7.0      17.0     26.0     20.0                     6
#
#   smartway
# 0       no
# 1       no
# 2       no
# 3      yes
# 4      yes

# %%
df_08v4.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                float64
# hwy_mpg                 float64
# cmb_mpg                 float64
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
df_18v4.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                float64
# hwy_mpg                 float64
# cmb_mpg                 float64
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
all(df_08v4.dtypes == df_18v4.dtypes)
# Out:
# True

# %%
df_08v4.to_csv('clean_08.csv', index=True)
df_18v4.to_csv('clean_18.csv', index=True)

# %% [markdown]
# # EXPLORING WITH VISUALS

# %%
# %matplotlib inline
clean_08 = pd.read_csv('clean_08.csv')
clean_18 = pd.read_csv('clean_18.csv')

# %%
clean_08.hist();

# %%
clean_18.hist();

# %%
clean_08.plot.scatter(x="displ", y="cmb_mpg");

# %%
clean_18.plot.scatter(x="displ", y="cmb_mpg");

# %%
clean_08.plot.scatter(x="greenhouse_gas_score", y="cmb_mpg");

# %%
clean_18.plot.scatter(x="greenhouse_gas_score", y="cmb_mpg");

# %% [markdown]
# # CONCLUSIONS AND VISUALS

# %% [markdown]
# For this section use the solution in the Notebook titled, [drawing-conclusion-solution](./Ideal%20Solution/drawing-conclusions-solutions.ipynb)

# %% [markdown]
# # TYPES OF MERGES

# %% [markdown]
# ## MERGING DATASETS

# %%
m08 = pd.read_csv('clean_08.csv')
m18 = pd.read_csv('clean_18.csv')

# %%
# rename 2008 columns
m08.rename(columns=lambda x:x[:10] + "_2008", inplace=True)

# %%
m08.head()
# Out:
#    Unnamed: 0_2008 model_2008  displ_2008  cyl_2008 trans_2008 drive_2008  \
# 0                0  ACURA MDX         3.7         6    Auto-S5        4WD
# 1                1  ACURA RDX         2.3         4    Auto-S5        4WD
# 2                2   ACURA RL         3.5         6    Auto-S5        4WD
# 3                3   ACURA TL         3.2         6    Auto-S5        2WD
# 4                4   ACURA TL         3.5         6    Auto-S5        2WD
#
#   fuel_2008 veh_class_2008  air_pollut_2008  city_mpg_2008  hwy_mpg_2008  \
# 0  Gasoline            SUV              7.0           15.0          20.0
# 1  Gasoline            SUV              7.0           17.0          22.0
# 2  Gasoline    midsize car              7.0           16.0          24.0
# 3  Gasoline    midsize car              7.0           18.0          26.0
# 4  Gasoline    midsize car              7.0           17.0          26.0
#
#    cmb_mpg_2008  greenhouse_2008 smartway_2008
# ...

# %%
# merge datasets
m_combined = pd.concat([m08, m18], axis=1, join='inner')

# %%
# view to check merge
m_combined.head()
# Out:
#    Unnamed: 0_2008 model_2008  displ_2008  cyl_2008 trans_2008 drive_2008  \
# 0                0  ACURA MDX         3.7         6    Auto-S5        4WD
# 1                1  ACURA RDX         2.3         4    Auto-S5        4WD
# 2                2   ACURA RL         3.5         6    Auto-S5        4WD
# 3                3   ACURA TL         3.2         6    Auto-S5        2WD
# 4                4   ACURA TL         3.5         6    Auto-S5        2WD
#
#   fuel_2008 veh_class_2008  air_pollut_2008  city_mpg_2008  ...       trans  \
# 0  Gasoline            SUV              7.0           15.0  ...  SemiAuto-6
# 1  Gasoline            SUV              7.0           17.0  ...  SemiAuto-6
# 2  Gasoline    midsize car              7.0           16.0  ...       AMS-8
# 3  Gasoline    midsize car              7.0           18.0  ...  SemiAuto-9
# 4  Gasoline    midsize car              7.0           17.0  ...  SemiAuto-9
#
# ...

# %%
m_combined.to_csv('combined_dataset.csv', index=False)

# %% [markdown]
# # RESULTS WITH MERGED DATASET

# %%
merge_combined = pd.read_csv('combined_dataset.csv')

# %%
model_mpg = merge_combined.groupby('model')[['cmb_mpg_2008', 'cmb_mpg']].mean()

# %%
model_mpg.head()
# Out:
#                       cmb_mpg_2008  cmb_mpg
# model
# ACURA RDX                     18.0     22.5
# ACURA TLX                     20.0     25.0
# ACURA TLX AWD A-SPEC          21.0     23.0
# ACURA TLX FWD A-SPEC          22.0     23.0
# ALFA ROMEO 4C                 23.0     28.0

# %%
mpg_change = model_mpg.cmb_mpg - model_mpg.cmb_mpg_2008

# %%
model_mpg['mpg_change'] = mpg_change

# %%
model_mpg.head()
# Out:
#                       cmb_mpg_2008  cmb_mpg  mpg_change
# model
# ACURA RDX                     18.0     22.5         4.5
# ACURA TLX                     20.0     25.0         5.0
# ACURA TLX AWD A-SPEC          21.0     23.0         2.0
# ACURA TLX FWD A-SPEC          22.0     23.0         1.0
# ALFA ROMEO 4C                 23.0     28.0         5.0

# %%
max_change = model_mpg['mpg_change'].max()

# %%
model_mpg[model_mpg['mpg_change'] == max_change]
# Out:
#                 cmb_mpg_2008  cmb_mpg  mpg_change
# model
# CHEVROLET Volt          20.0     74.0        54.0

# %%
idx = model_mpg.mpg_change.idxmax()
idx
# Out:
# 'CHEVROLET Volt'

# %%
model_mpg.loc[idx]
# Out:
# cmb_mpg_2008    20.0
# cmb_mpg         74.0
# mpg_change      54.0
# Name: CHEVROLET Volt, dtype: float64
